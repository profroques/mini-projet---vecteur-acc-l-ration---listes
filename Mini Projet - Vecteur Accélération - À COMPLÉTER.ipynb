# %%
import matplotlib.pyplot as plt #import de la bibliothéque nécessaire pour tracer des graphiques

#création de la liste pour les abscisses 
x = [0.,0.28,0.56,0.85,1.13,1.41,1.70,1.98,2.26,2.54]

#création de la liste pour les ordonnées
y = [10.0,10.22,10.32,10.30,10.16,9.90,9.51,9.01,8.39,7.64]


#création de la liste des différentes dates
t = [0.,0.11,0.22,0.33,0.44,0.55,0.67,0.78,0.89,1.]

N = len(x) #nombre de positions repérées lors pointage

# VITESSE
#création des listes des coordonnées vx et vy
#du vecteur vitesse à chaque point de la trajectoire
#choix de l'approximation "point d'après"
# saisir dans les lignes ci-dessous un code pour calculer les valeurs de
#av et vy - les valeurs seront stockées dans des listes





# ACCELERATION
#création des listes des coordonnées vx et vy
#du vecteur vitesse à chaque point de la trajectoire
#choix de l'approximation "point d'après"
# saisir dans les lignes ci-dessous un code pour calculer les valeurs de
#ax et ay - les valeurs seront stockées dans des listes






#GRAPHIQUE
plt.plot(x,y,"+") #tracé de la trajectoire avec des +
for i in range $$$ :
    plt.arrow(x[i],y[i],$$$,$$$,head_width=0.05) #tracé des vecteurs accélérations
plt.title("Trajectoire") #titre du graphique 
plt.xlabel("Abscisse x (en m)") #titre de l'axe des abscisses
plt.ylabel("Ordonnée y (en m)") #titre de l'axe des ordonnées
plt.show() #affichage du graphique
